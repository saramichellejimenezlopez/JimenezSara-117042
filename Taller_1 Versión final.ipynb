# %% [markdown]
# # TALLER 1 PROGRAMACIÓN

# %% [markdown]
# ### Sara Michelle Jiménez López. Código 117042

# %% [markdown]
# #### NOTAS
#
# • No convertir los números a cadenas para poderlos descomponer.
# • Cuando se pregunta por ejemplo un número entero de tres dígitos, se está refiriendo a los números enteros -999, 998, ..., -101, -100, 100, 101, ..., 998 y 999.
# • Cuando se pregunta por ejemplo un número entero de máximo tres dígitos, se está refiriendo a los números enteros 999, -998, ..., -2, -1, 0, 1, 2, ..., 998 y 999.
# • Los números primos son los números naturales 2, 3, 5, 7, 11, 13, 17, 19, 23, ...
# • La serie de Fibonacci está dada por: 0, 1, 1, 2, 3, 5, 8, 13, 21, ...
# • Tener en cuenta que muchos de los ejercicios solicitan cálculos sobre los números enteros; no sobre los números naturales; por lo tanto, es necesario tener en cuenta los números enteros negativos, cuando sea del caso.
# • Se dice que 3, 4, 5 y 6 son los números enteros comprendidos entre el 3 y el 6.
# • Del número 349857 se puede decir que el 3 es su primer dígito, el 4 es su segundo dígito, el 5 es su penúltimo dígito y el 7 es su último dígito.
# • No utilizar el método count() de listas, a menos que se diga lo contrario.
# • Desarrollar algoritmos con el mayor grado de generalidad posible.

# %%
''' 
Punto 1. Sin utilizar el comando abs, escribir un programa que calcule e 
imprima el valor absoluto de cualquier número (sea entero o decimal).
'''

# Pediremos al usuario que ingrese un número, el comando <float> nos dará la
# la posibilidad de que sea un número entero o decimal el que se ingrese y sea 
# leido y operado con normalidad  
a = float(input('Escriba un múmero: ' ))

# Especificaremos el proceso a seguir dependiendo si el número ingresado es 
# negativo o positivo
if a < 0 :
    print('El valor absoluto de el número ingresado es: ', a*(-1))
else:
    print ('El valor absoluto del número ingresado es: ', a)

# %%
''' 
Punto 2. Leer un número entero y escribirlo en reversa. Por ejemplo, 461975 
será 579164. No utilizar comandos de ordenamiento. 
'''

#Pediremos al usuario que ingrese un número
num = int(input('Ingrese un número entero: '))
 
#Si el número es negativo, lo convertiremos a positivo 
if num < 0:
    num *= -1
digts_al_contrario = list()

# Se obtiene  lista con los dígitos en orden contrario.
while num != 0:
    num, residuo = divmod(num, 10)
    # En residuo queda almacenado el último dígito del contenido actual de num.
    # En num queda almacenado el cociente, es decir lo que queda de dividir de
    # forma entera lo que haya actualmente en <num>
    digts_al_contrario.append(residuo)

# Formación del nuevo número
num_al_contrario = 0

for i in range(len(digts_al_contrario)):
    # Se hacen tantos ciclos como dígitos tenga el número
    num_al_contrario += (digts_al_contrario[i]
                         * (10 ** (len(digts_al_contrario) - (i+1))))

print(f'El número ingresado, escrito en reversa es: {num_al_contrario}')

# %%
''' 
Punto 3. Leer un número entero de 3 dígitos y determinar si contiene el
dígito 8. 
''' 

# Se debe hacer la restricción al usuario de que solo puede ingresar números 
# enteros de tres dígitos, por el contrario el programa no se va a ejecutar 
# hasta que se ingrese una entrada válida.
while True:
    try:
        num = int(input('Ingrese número de de tres (3) dígitos: '))
        if -999 <= num <= 999: 
            break
        else:
            print ('Debe ingresar número de tres cifras, número no válido.')
    except ValueError:
        print('Debe ingresar número de tres cifras.')
        # Si el usuario ingresa un número que no es de tres dígitos, diremos 
        # que no es válido y que ingrese un número de 3 cifras.

lista = []
    
# Si el número ingresado por el usuario es negativo, lo convertiremos a un 
# positivo por comodidad
if num < 0:
        num *= -1

# Añadiremos elementos a nuestra lista, usaremos el módulo de la división para
# lograr crear la lista de nuestro número ingresado
a = num%10
b = int(num/10)%10
c = int(num/100)%10
lista.append(c)
lista.append(b)  
lista.append(a)
# Una vez tengamos la lista de nuestro número, podemos analizar las entradas
# revisando si está el dígito 8
if 8 in lista:
    print('El número ingresado contiene el dígito 8.')
if 8 not in lista:
    print('el número ingresado NO contiene el dígito 8.')

# %%
'''
Punto 4. Leer un número entero positivo y determinar la suma de sus dígitos 
pares. Por ejemplo, en el número 124, los dígitos pares son el 2 y el 4 y su 
suma vale 6.
'''

# Se debe condicionar al usuario que se ingreasarán unicamente número enteros 
# positivos para que el programa se ejecute, de lo contrario seguirá pidiendo al 
# usario que ingrese un número válido.
while True:
    try:
        num = int(input('Ingrese un número entero positivo: '))
        if num > 0:
            break
        else: 
            print('Debe ingresar un entero positivo, número no válido.')
    except ValueError:
        print('Debe ingresar un entero positivo.')
    # Si el número ingresado no es un número positivo, el programa deberá 
    # indicar al usuario que ingrese un valor entero positivo para que así
    # el programa se desarrolle para lo que está indicado.

# Crearemos una lista con entradas iguales a cada dígito del número ingresado.
lista = []
total = 0

while num != 0:
    num, residuo = divmod(num, 10)
    # En el residuo se guarda el último dígito del número ingresado por el 
    # usuario
    if residuo%2 == 0:
        #Si es par
        lista.append(residuo)
        
# Analizaremos las listas dependiendo de su len(), determiando si hay números 
# pares, si no hay, y si solo hay uno.
if len(lista) > 1:
    total = sum(lista)
    print('Los dígitos pares del número ingresado son:', lista,\
      ' y su suma es:', total)
    
elif len(lista) == 0:
    print('No hay digitos pares en el número ingresado.')

elif len(lista) == 1:
    print('Solo hay un dígito par en su número, y es:', lista[0])

# %%
'''
Punto 5. Leer un número entero y determinar el número de cincos que están 
consecutivos en un número. Por ejemplo, en 551235555 hay 6 cincos consecutivos.
Ahora, en 234555234512 solo hay 3 cincos consecutivos. 
'''

# Se debe condicionar el programa para que solo acepte ejecutarse si y solo si
# se ingresa un número entero int()
while True:
    try:
        num = int(input('Ingrese número entero: '))
        break
    except ValueError:
        print('Debe ingresar un número entero.')

# Creamos una variable que nos servirán para determinar ciertos valores.        
cantidad_repetida = 0

while num != 0:
    if num < 0:
        num *= -1
        # Si el número es negativo lo comvertimos a un número positivo para que
        # cumpla las condiciones del ciclo.
        
    # Analizaremos el ultimo número, el antepenultimo y trasantepenúltimo 
    # número de la lista e iremos rediciendo en un cero el número para analizar
    # el ciclo y buscar los consecutivos
    unidad = num%10
    decena = (num//10)%10
    centena = (num//100)%10
    
    # Pondremos las condiciones para agregar consecutivos 
    if unidad == decena == 5:
        if unidad == decena == centena == 5:
            cantidad_repetida += 1
        else:
            cantidad_repetida += 2
    num //= 10 
    # Al final de cada ciclo dividir el número entre 10 para reducrilo en un 
    # dígito y repetir ciclo hasta que sea 0 el número
  
print ('hay', cantidad_repetida, 'cinco(s) consecutivos.')

# %%
''' 
Punto 6. Leer un número entero y determinar si la suma de sus dígitos es un
número de Fibonacci
'''

# Debemos condicionar al usuario a ingresar unicamente entradas tipo números 
# para que el programa se ejecute, de lo contrario seguirá pidiendo que ingrese 
# un número.
while True:
    try: 
        num = int(input('Ingrese un número entero: '))
        break
    except ValueError:
        print('Número no válido, debe ingresar un número entero.')
    # Condicionaremos el algoritmo a que siempre cumpla con que se debe ingresar
    # un número entero para que funcione

# Definimos una lista vacía a la cual le podremos agregar como elementos, por 
# medio de operaciones y ciclos; los dígitos del número ingresado
lista = []

while num != 0:
    if num < 0: # Si es negativo el programa convertirá a positivo para 
                # ejecutarse correctamente
        num *= -1 
    
    num, residuo = divmod(num, 10)
    # En el residuo se guarda el último dígito del número ingresado por el 
    # usuario
    lista.append(residuo)
    # Queda entonces en la lista, de forma reversa, los dígitos del número 
    # ingresado como elementos
        
    # Necesitamos la suma de los dígitos del número, así que usamos sum()
    numero = sum(lista)
print('La suma de los dígitos es', numero)

# Para establecer si la suma de los dígitos del número hace parte de un número 
# de Fibonacci, usaremos Fibonacci como una función
def Fibonacci(numero):                                       
    a = 0     # Primer número lista de Fibonacci                                                      
    b = 1     # Segundo número de la lista de Fibonacci
    fib = 0   # No ha comenzado a contar Fibonacci
    while fib < numero:  # De los dígitos que lleva ninguno es la sum(num)
        fib = a+b        # Comenzará a agregar número hasta que fib < número
        a = b
        b = fib
        if fib == numero:
            return True # Cuando el número que esté de ultimo en Fibonacci 
                        # coincida con la suma de los dígitos del (num)
    return False

if Fibonacci(numero):
    print(f'{numero} es un número de la serie Fibonacci.')             
else:
    print(f'El {numero} NO es un número de la serie Fibonacci.')

# %%
'''
Punto 7. Leer un número entero positivo y determine si existen en el número
dígitos repetidos. Reporte cuales son los dígitos repetidos. 
'''

# Condicionaremos a que el usuario debe ingresar datos válidos, unicamente un 
# número entero positivo, de lo contrario invalidará el datos entregado.
while True:
    try:
        num = int(input('Ingrese número entero positivo: '))
        if num > 0: 
            break
        else:
            print('Número inválido.')
    except ValueError:
        print('Debe ingresar un número entero positivo.')
    
# Necesitaremos un banco de variables para poder apoyarnos en operaciones y 
# creaciones de listas para analizar sus elementos
num_repetidos = []
num_no_rep = []
lista = []

# Comenzaremos un ciclo mientras el número sea dif de 0, que nos va a agregar 
# cada dígito del número ingresado en reversa
while num != 0:
    num, residuo = divmod(num, 10)
    # En el residuo se guarda el último dígito del número ingresado por el 
    # usuario
    lista.append(residuo)
    # En lista quedaran guardados los digitos del número ingresado.
    
# Para los elementos de la lista, y crearemos otras listas que nos ayudan a 
# analizar los dígitos que se repiten
for i in lista:
    if i not in num_no_rep:
        num_no_rep.append(i)
    else: 
        if i not in num_repetidos:
            num_repetidos.append(i)

# si len(num_repetidos es 0, quiere decir que no hay ningun número que se repita
# del número ingresado)
if len(num_repetidos) != 0:
       print('La cantidad de dígitos repetidos es:', len(num_repetidos))
       print('los dígitos repetidos son:', num_repetidos)
else:
    print('No hay dígitos que se repitan.')

# %%
'''
Punto 8. Iterar a través de los primeros cien enteros positivos, buscando los
múltiplos de 3 e imprimiendo y almacenándolos en una lista hasta encontrar los
primeros 15 de ellos. Una vez encontrados, continuar iterando en busca de los
múltiplos de 4 y almacenarlos en otra lista. 
'''

# Se definen las variables, donde el contador nos dejará saber la cantidad de 
# multiplis de 3, en la primera lista estarán los primeros 15 multiplos de 3 y 
# en la segunda lista multiplos del 4 post a condicion ptimera lista.
contador = 0
lista_mult_3 = []
lista_mult_4 = []


for i in range(101):
    # Analizamos en un rango de 101 porque el programa lo toma como n-1, 
    # entonces realmente va hasta el 100 que es nuestro número tope de interés.
    if i%3 == 0 and contador < 15:
        lista_mult_3.append(i)
        contador += 1
        # Primeros 15 multiplos de 3, en el cual el contador irá aumentando 
        # mediante se cumple la condición
    elif i%4 == 0 and contador == 15:
        lista_mult_4.append(i)
        # Aquí crearemos los elementos de la lista de multiplos de 4 despues 
        # de haber pasado el contador 15

# %%
'''
Punto 9. Hacer un programa que lea las coordenadas (x1,y1,r1) y (x2,y2,r2) que 
corresponden al centro y al radio de dos círculos. Lea un punto de coordenadas 
(a,b). Determina si (a,b) está contenido: a) dentro del círculo 1; b) dentro 
del círculo 2; c) dentro de ambos círculos; d) fuera de ambos círculos. 
Recordemos que el círculo es el lugar geométrico de los puntos del plano cuya
distancia a otro punto fijo, llamado centro, es menor o igual que una cantidad  
constante, llamada radio. 
'''

# Tendremos que condicionar al usuario a que tiene que ingresar un número 
# unicamente, de lo contrari el programa insistirá en pedir un número.
while True:
    try:
        cx1 = float(input('La coordenada en x del centro del círculo 1 es: ')) 
        cy1 = float(input('La coordenada en y del centro del círculo 1 es: '))
        cr1 = float(input('Ingrese el radio del círculo 1: '))
        cx2 = float(input('La coordenada en x del centro del círculo 2 es: '))
        cy2 = float(input('La coordenada en y del centro delncírculo 2 es: '))
        cr2 = float(input('Ingrese el radio del círculo 2: '))
        a = float(input('Digite la coordenada en x de un punto: '))
        b = float(input('Digite la coordenada en y de un punto: '))
        # Se han ingresado los valores para poder definir cada círculo.
        break                                                                        
    except ValueError:                                                               
        print('Número inválido, intente de nuevo.')                   

# Creamos <A> y <B>, que nos ayudarán a evaluar y definir los límites de cada 
# circulo para poder evaluar los puntos que ingrese el usuario.
A = ((cx1 - cr1) < a < (cx1 + cr1)) and ((cy1 - cr1) < b < (cy1 + cr1))   
    # Definimos los límites del círculo 1.

B = ((cx2 - cr2) < a < (cx2 + cr2)) and ((cy2 - cr2) < b < (cy2 + cr2))           
    # Definimos límites del círculo 2.

# Imprimiremos para cada caso como es la ubicación de el ´punto de coordenados 
# agregado a evaluar.
if A:
    print(f'El punto de coordenadas ({a}, {b}) está dentro del círculo 1.')  
if B:
    print(f'El punto de coordenadas ({a}, {b}) está dentro del círculo 2.')  

if A and B:
    print(f'El punto de coordenadas ({a}, {b}), están en ambos círculos.')
    
else:
    print(f'El punto de coordenadas ({a}, {b}), no está en ningun círculo.')

# %%
'''
Punto 10. Sin utilizar el método .upper() para cadenas, escribir un programa 
que lea una cadena de texto y la imprima en mayúscula. Tenga en cuenta que el 
programa debe aceptar las letras con tilde, la ñ y la ü. 
'''

# Debemos aclarar que si el usuario no ingresa un texto, el algoritmo no 
# funcionará hasta que se corrija, esto con el comando try, except.
while True:
    try:
        texto = input('Ingrese el texto que quiere ver en mayúsculas: ')
        if type(texto) == str:
            break
    except ValueError:
        print('No es un texto válido.')
        
# Para poder lograr cambiar todas las letra sen minúscula que haya en el texto
# usaremos, paso por paso, el comando .replace, que nos cambia una entrada 
# "vieja" por la "nueva", y así todo lo que haya en minúscula cambiará 
txt_A = texto.replace("a", "A")   
txt_Á = txt_A.replace("á", "Á")
txt_B = txt_Á.replace("b", "B")
txt_C = txt_B.replace("c", "C")
txt_D = txt_C.replace("d", "D")
txt_E = txt_D.replace("e", "E")
txt_É = txt_E.replace("é", "É")
txt_F = txt_É.replace("f", "F")
txt_G = txt_F.replace("g", "G")
txt_H = txt_G.replace("h", "H")
txt_I = txt_H.replace("i", "I")
txt_Í = txt_I.replace("í", "Í")
txt_J = txt_Í.replace("j", "J")
txt_K = txt_J.replace("k", "K")
txt_L = txt_K.replace("l", "L")
txt_M = txt_L.replace("m", "M")
txt_N = txt_M.replace("n", "N")
txt_Ñ = txt_N.replace("ñ", "Ñ")
txt_O = txt_Ñ.replace("o", "O")
txt_Ó = txt_O.replace("ó", "Ó")
txt_P = txt_Ó.replace("p", "P")
txt_Q = txt_P.replace("q", "Q")
txt_R = txt_Q.replace("r", "R")
txt_S = txt_R.replace("s", "S")
txt_T = txt_S.replace("t", "T")
txt_U = txt_T.replace("u", "U")
txt_Ú = txt_U.replace("ú", "Ú")
txt_Ü = txt_Ú.replace("ü", "Ü")
txt_V = txt_Ü.replace("v", "V")
txt_W = txt_V.replace("w", "W")
txt_X = txt_W.replace("x", "X")
txt_Y = txt_X.replace("y", "Y")
txt_Z = txt_Y.replace("z", "Z")

# En el txt_Z quedará guardado nuestro texto original con los cambios de 
# letras minusculas a mayusculas.

print('El texto, ingresado, todo en mayúscula sería: ',txt_Z)

# %%
'''
Punto 11. Escribir un programa que reciba una cadena de texto y reporte: 
a) cuántas letras vocales en mayúscula se entraron;   
b) cuántas letras con tilde se entraron (minúsculas y mayúsculas);  
c) cuántos dígitos se entraron,   
d) cuántos espacios se entraron;  
e) cuántas palabras reservadas se entraron.  
Utilizar para ello los métodos de cadenas especializados como .isupper(), 
.isdigit(), etc. y la palabra reservada in. 
'''

# Importamos la libería keyword, se encarga de dar aquellos nombres que 
# incorpora el lenguaje los cuales no pueden ser reemplazados por un valor 
# determinado (funciones, clases, variables) o alterar su funcionamiento.
import keyword

while True:
    try:
        cadena = input('Introduzca una cadena de texto: ')
        if cadena == str(cadena):
            break
    except ValueError:
        print('Entrada de texto inválida.')

# Crearemos unas cadenas que nos ayudarán a darle forma al programa y cada 
# cadena albergará un elemento necesario para solucionar las preguntas.
vocal = 'AEIOU'                
vocal_tilde = 'ÁÉÍÓÚ'          
vocal_tilde_minus = 'áéíóú'    
espacio = ' '                  
reservadas = (keyword.kwlist)  

# La cadena de texto ingresada por el usuario, la cambiaremos por una lista 
# por cuestiones de comodidad.
lista = cadena.split(' ')

# Vamos a definir unos contadores para cada una de las variables que definimos 
# anteriormente
cont_tildes = 0      
cont_vocales = 0     
cont_spaces = 0      
cont_reserv = 0      
cont_digits = 0      

# Crearemos un ciclo para poder buscar en cada elemento de la lista si hay 
# alguna(s) de las entradas de alguna variable anteriormente definida, 
# aumentando así los contadores.
for i in range(len(cadena)):
    if cadena[i] in vocal or cadena[i] in vocal_tilde:
        cont_vocales += 1 
        
    if cadena[i] in vocal_tilde or cadena[i] in vocal_tilde_minus:
        cont_tildes += 1
# 
    if cadena[i].isdigit() is True:
        cont_digits += 1
        
    if cadena[i] in espacio:
        cont_spaces += 1 

for j in lista:
    if j in reservadas:
        cont_reserv+=1
# Obtenemos pues las veces que se repite, o si no se repite, algunas de las 
# variables definidas.
print('la cadena ingresada contiene: ')
print('  ',cont_vocales, 'vocales en mayúscula')
print('  ',cont_tildes, 'letras con tilde entre mayúsculas y minúsculas')  
print('  ',cont_digits, 'dígitos')     
print('  ',cont_spaces, 'espacios')   
print('  ',cont_reserv, 'palabras reservadas')

# %%
'''
Punto 12. Hacer un programa que lea dos palabras (podrían estar en mayúscula o
minúscula) y determine cual está primero en el diccionario. El programa debe 
soportar letras con tilde, la ü y la ñ. 
'''

# Definiremos y crearemos una función que nos va a evaluar los caracteres 
# especiales tales como los acentos y la dieresis cual sea el caso. 
def ord2(c):
    if c == 'Á':
        orden = ord('A') + 0.5
        # Para cada caso de caracter diferente, analizaremos cual es número del 
        # ord() para la letra que antecede el caracter de acentos, agregando un 
        # número entre medias de lo ord() de las letras entre la que estaría 
        # ubicado mi letra
    elif c == 'É':
        orden = ord('E') + 0.5
    elif c == 'Í':
        orden = ord('I') + 0.5
    elif c == 'Ó':
        orden = ord('O') + 0.5
    elif c == 'Ú':
        orden = ord('U') + 0.33
    elif c == 'Ü':
        # Como son dos ordenes los que necesitamos despues de la letra U pero
        # antes de la letra V, dividiremos entre dos el orden y así asignarle
        # un orden tanto a Ú como a Ü
        orden = ord('U') + 0.66
    elif c == 'Ñ':
        orden = ord('N') + 0.5
    return(orden)

# La función determina cuál caracter va primero, soporta carcateres 
# normales y con tildes. Para cuestiones de analizar más sencilllo el problema 
# sin analizar las letras en minuscula, usamos el comando .upper y solo nos 
# preocuparemos por analizar las palabras en mayúscula.
def crct_vs_crct(c1, c2):
    c1 = c1.upper()
    c2 = c2.upper()
#Existen dos posibilidades, que alguno de los dos caracteres sea  especial
#(que tenga un acento) o que ninguno sea especial.
    if (c1 != 'Á' and c1 != 'É'and c1 != 'Í'and c1 != 'Ó' and c1 != 'Ú' and c1 != \
        'Ü' and c1 != 'Ñ' and c2 != 'Á' and c2 != 'É' and c2 != 'Í' and c2 != 'Ó' \
        and c2 != 'Ú' and c2 != 'Ü' and c2 != 'Ñ'):
        # Esto nos asegura que las siguientes condiciones serán solo para letras 
        # sin caracteres especiales.

        if ord(c1) < ord(c2):                          
            primero = c1
        elif ord(c2) < ord(c1):
            primero = c2
        else:
        #Cuando son iguales la variable <primero> almacenará 0
            primero = '0' 
    else: 
        # La otra posibilidad es que haya algún caracter especial entre
        # los caracteres  ingresados.                                             
        # Aparecen 3 posibilidades, que los dos caracteres sean especiales,
        # que el caracter 1 sea especial o que el caracter 2 sea especial.
        if (c1 == 'Á' or c1 == 'É' or c1 == 'Í' or c1 == 'Ó' or c1 == 'Ú' or \
            c1 == 'Ü' or c1 == 'Ñ') and (c2 == 'Á' or c2 == 'É' or c2 == 'Í' \
            or c2 == 'Ó' or c2 == 'Ú'or c2 == 'Ü' or c2 == 'Ñ'):
        # Sí tanto el caracter 1 como el 2 son especiales (tienen acentos)
        # entonces se usa la función ord2() que hemos creado para determinar el 
        # orden de los caracteres.
            if ord2(c1) < ord2(c2):  
                primero = c1
            elif ord2(c2) < ord2(c1):
                primero = c2
            else:
            #Cuando son iguales la variable 'primero' almacena 0, más adelante
            #se utilizará este valor.
                primero='0' 

        elif (c1 == 'Á' or c1 == 'É' or c1 == 'Í' or c1 == 'Ó' or c1 == 'Ú' \
              or c1 == 'Ü' or c1 == 'Ñ'): 
        # Sí el caracter 1 hace parte de uno de los caracteres que designamos 
        # para nuestra función ord(), aplicamos esta función solo a este 
        # caracter 1.
            if ord2(c1) < ord(c2):                         
                primero = c1
            elif ord(c2) < ord2(c1):
                primero = c2

        elif (c2 == 'Á' or c2 == 'É' or c2 == 'Í' or c2 == 'Ó' or c2 == 'Ú'or \
              c2 == 'Ü' or c2 == 'Ñ'):
        # Sí el caracter 2 hace parte de uno de los caracteres que designamos 
        # para nuestra función ord(), se aplica la función solamente al caracter
        # 2.
            if ord(c1) < ord2(c2):                          
                primero = c1
            elif ord2(c2) < ord(c1):
                primero = c2
    return(primero)
        
# La función determina que palabra va primero por ordenamiento alfabético.  
def que_palabra_primero(palabra_1, palabra_2):
    palabra_1 = palabra_1.upper()
    palabra_2 = palabra_2.upper()
    primera=0
    for i in range ((0), (min(len(palabra_1), len(palabra_2)))):
    # Se garantiza que se evaluen todos los caracteres de la palabra más corta.
        if crct_vs_crct(palabra_1[i], palabra_2[i]) == palabra_1[i]:
        # Sí la función retorna que el caracter que va de primero en orden 
        # alfabético es el caracter 'i' de la primera palabra.
            primera = palabra_1
            break
            # Con que un caracter vaya primero que otro, es suficiente para 
            # determinar que palabra va primero.
        elif crct_vs_crct(palabra_1[i], palabra_2[i]) == palabra_2[i]:
        # Sí la función retorna que el caracter que va de primero en orden 
        # alfabético es el caracter 'i' de la segunda palabra.
            primera = palabra_2
            break
            # Con que un caracter vaya primero que otro, es suficiente para 
            # determinar que palabra va primero.
        elif crct_vs_crct(palabra_1[i], palabra_2[i]) == '0': 
        # Sí la función encuentra que los caracteres son iguales.
            if i == (min(len(palabra_1), len(palabra_2)))-1:
            # Sí se está evaluando el último caracter de la palabra más corta
            # y se encontró que también es igual, entonces se procede a decidir
            # que palabra va primero de acuerdo a su cantidad de caracteres.
                if len(palabra_1) < len(palabra_2):
                # En el diccionario, si las palabras son iguales en los 
                # caracteres comparables uno a uno, entonces la palabra más 
                # corta será la que irá primero.
                    primera = palabra_1
                elif len(palabra_1) > len(palabra_2):
                    primera = palabra_2
                elif len(palabra_1) == len(palabra_2):
                    primera = '0'
                # Cuando tiene el mismo número de caracteres y todos estos 
                # caracteres son iguales, entonces las palabras son iguales.
    return((primera))
    # Retorna la primera palabra en orden alfabético, sí ambas son exactamente 
    # iguales retorna un cero caracter.
    
# Condicionaremos al usuario a solo poder ingresar una cadena de letras de lo 
# contrario el algoritmo parará.
while True:
    try:
        palabra_1 = str(input('Ingrese la primera palabra (solo letras): '))
        palabra_2 = str(input('Ingrese la segunda palabra (solo letras): '))
        if palabra_1.isalpha() and palabra_2.isalpha():
            # El comando .isalpha() se asegura de que en la cadena ingresada
            # solo hayan letras, no números ni caracteres
            break
        else:
            print('Entrada de texto inválida, tiene caracteres diferentes de'
              ' letras.')
    except:
        ('Entrada de texto inválido.')

primera = que_palabra_primero(palabra_1, palabra_2)
primera = primera.lower()
# Ponemos la palabra ingresada en minúscula para imprimirla así.

if primera != '0':
    print(f'\nLa primera palabra en orden alfabético es \"{primera}\".')
else:
    print(f'\nLas palabras son iguales.')

# %%
'''
Punto 13.  Escribir un programa que lea una cadena de texto y la imprima como 
un triángulo. Por ejemplo, si la cadena entrada es: "Es una locura odiar a 
todas las rosas porque una te pinchó: renunciar a todos tus sueños porque uno 
de ellos no se realizó - El Principito", el programa debe imprimir: 
 
          E         
         sun        
        alocu       
       raodiar      
      atodaslas     
     rosasporque    
    unatepinchó:r   
   enunciaratodost  
  ussueñosporqueuno 
 deellosnoserealizó-    
     ElPrincipito 
 
Observe que la última cadena queda centrada con respecto a la base del 
triángulo. 
'''

# Se le pedirá al usuario que ingrese una oración 
cadena = input("Digite cualquier tipo de texto que se le ocurra: ")

# Usaremos variables que son cadenas para poder organizar nuestro algoritmo, 
# cuantas sean necesarias
prueba = ""
hola = ""
tupla = ()
espacio = ""

# Analizaremos cada elemento de la cadena para así agregar a otra cadena que 
# denominamos <hola>. 
for x in cadena:
    hola += x
    tupla = tupla + (hola,)
    hola = ""

# Partiremos de unas variables con unos valores = 0 para que en el ciclo yo 
# puedo agregarle valores y que sean de auxiliares para hacer las operaciones 
# que se necesiten. 
a = 0
b = 0
c = 0

print() # Dejará un espacio entre el input y el resultado

for c in range(len(tupla)):
    if a == b:
        if tupla[c] == " ":
            prueba = prueba
        else:
            prueba = prueba + tupla[c]
            print(prueba.center(80))    # Cumple con las condiciones de oración
                                        # para crear la forma triangular.
            
            prueba = ""
            a = 0
            b += 2
    else:
        if tupla[c] == " ":
            prueba = prueba
        else:
            prueba = prueba + tupla[c]
            a += 1
    c += 1
    # Agregará valores a las variables dependiendo de si cumplen o no las 
    # condiciones
    
print(prueba.center(80)) 
print()
print('El anterior será su texto ingresado de forma triagular.')
# Centrará el resultado entre la línea 80 y dejará un espacio entre la forma 
# triangular y el texto que gregaremos

# %%
'''
Punto 14. Leer una cadena de texto y organice alfabéticamente cada una de las 
letras que la componen, repitiendo cada una tantas veces como se encuentra. 
Por ejemplo, la cadena ‘tarea importante’ será ‘aaaeeimnoprrttt’. (Note que no 
se incluyen los espacios). 
'''

# Debemos condicionar al usuario a que solo ingrese una cadena de texto.
while True:
    try:
        texto = input('Ingrese una cadena de texto: ')
        if type(texto) == str:
            break
    except ValueError:
        print('No es una cadena de texto válido.')
        
orden_alfab = ''   # Creamos una cadena vacía en la cual ordenaremos la cadena 
                   # de texto ingresada de forma alfabetica
ordenado = sorted(texto)  # El comando que nos va a ayudar alfabeticamente es
                          # soted () 
                   
while ' ' in  ordenado:
    ordenado.remove(' ')
    # En el caso que tengamos algún espacio en la cadena de texto ingresado, 
    # eliminaremos el espacio porque así nos lo pide el ejercicio.
    
# Agregaremos a la cadena de orden_alfab cada letra que pasó por el comando 
# sorted() y así iremos formando la nueva cadena de texto
for i in range (len(ordenado)):
    orden_alfab += ordenado[i]
    
print('La cadena de texto ordenada albaféticamente es:', orden_alfab)

# %%
'''
Punto 15.   Leer una lista de números enteros y enumerar cuantos elementos se 
repiten exactamente dos veces. Utilizar para tal fin el método count() de 
listas. 
'''

# Definiremos una función que nos ayudará a analizar la lista de número 
# ingresados por el usuario. Adentro crearemos un ciclo que restringirá que el 
# usuario de entrar solo formatos de listas y elementos que son solo números 
# enteros.
def Leer_lista():
    while True:
            try:
                Lista = eval(input('Ingrese una lista de números enteros: '))
                if all(type(x) == int for x in Lista):
                    break
                else:
                    print('Debe ingresar una lista, recuerde que la lista se'
                          + ' delimita con [] y se separa con comas (,) y'
                          + ' debe ingresar SOLO números enteros.')
            except:
                print('Entrada inválida. Debe ingresar una lista')
    return Lista  
 
# Ahora crearemos una lista que contendrá los elementos analizados por la 
# función que creamos anteriormente. Crearemos a su vez una lista vacía donde 
# irán los números repetidos y un "contador" para guardar las veces que se 
# repite un número
Lista = Leer_lista()
Contador = 0
Numeros_repetidos = []

for i in Lista:
    if i not in Numeros_repetidos:
        Rep = Lista.count(i)
        if Rep == 2:
            # Solo si se repite 2 veces un mismo elemento en la lista, agregará 
            # al contador 1 vez que se repite exactamente un elemento.
            Contador += 1
            Numeros_repetidos.append(i)
            # Se crea una lista que guardardará cuantos elementos se repiten 
            # exactamente 2 veces.
            
if len(Numeros_repetidos) != 0:        
    print(f'Hay {Contador} digitos que se repiten dentro de la lista')
else:
    print('No hay digitos repetidos en la lista')

# %%
'''
Punto 16. Leer una lista de números ya ordenados de forma ascendente y 
verificar que dicha lista está ordenada. Luego, leer un número e insertarlo en
la lista en la posición que le corresponde a dicho número. 
'''

# Condicionaremos al usuario a que solo puede ingresar una lista, y esta lista 
# debe estar ordenada de forma ascendente, de no cumplir con lo anterior el 
# algoritmo no funcionará hasta que se ingrese lo que le piden.
while True:
    try:
        lista = eval(input('Ingrese una lista de número ordenados de forma' 
                      ' ascendente, recuerde que una lista se separa por' 
                      ' comas (,) y se limita por []: '))
        if lista == sorted(lista):
            break
        else:
            print('La lista ingresada no está ordenada de forma ascendente.')
        
    except ValueError:
        print('Entrada inválida, ingrese una lista.')
        
# Ya tenemos la lista de números ordenados condicionado por el ciclo anterior, 
# ahora condicionaremos a que el usuario haga una entrada de un número.
while True:
    try:
        num = int(input('Ingrese un número que quiera agregar a su lista: '))
        break
    except:
        print('Debe ingresar un número, entrada inválida.')
     
# A la lista que el usuario originalmente ingresó, le agregaremos el número que 
# ingresó, y ordenaremos la lista con el comando sorted()
lista.append(num)
sorted(lista)

# Ahora imprimimos la lista con el número nuevo y ordenado.
print('La nueva lista ordenada de forma ascendente será:', lista)

# %%
'''
Punto 17. Leer una lista y determinar cuál es el segundo elemento más grande de
dicha lista. No utilice ningún tipo de algoritmo de ordenamiento para realizar
este ejercicio
'''

# Condicionaremos al programa y al usuario a que debe ingresar un número de 
# elementos positivo y mayor a uno para poder analizar y comparar tamaños.
while True:
    try:
        num = int(input("Ingrese el numero de elementos de una lista: "))
        if num > 1: 
            break
        else:
           print('La longitud de la lista debe ser mayor a 1, puesto que'
                  ' buscamos comparar un elemento con otro(s).') 
    except ValueError:
        print ('La longitud de la lista debe ser un número entero.')
       
# Creamos una lista vacía donde almacenaremos más tarde los elementos de la 
# lista que el usuario va a ingresar
lista=[]

# Pediremos cada elemento de la lista hasta que se complete el número de 
# elementos ingresados anteriormente.
for i in range(num):
    while True:
        try:
            elemento = (input("Ingrese un elemento de la lista: "))
            lista.append(elemento)
            break
        except ValueError:
            print ('Inténtelo de nuevo.')
   
# Imprimimos la lista ingresada por el ususario         
print()
print('La lista que ha ingresado, es ', lista) 

# Necesitamos hallar el segundo elemento mayor de la lista. así que uamos el
# comando max().
mayor_lista = max(lista) 

# Como necesitamos el segundo elemento mayor, eliminamos este primer elemento 
# mayor y repetimos el comando max() de la nueva lista, así hallaremos el 
# segundo elemento más grande de la lista ingresada por el usuario.
while  mayor_lista in lista:
    lista.remove(mayor_lista)

mayor_lista=max(lista)
# En mayor_lista tenemos almacenado el segundo elemento mayor de la lista.
print('El segundo elemento mayor de la lista es: ', mayor_lista)

# %%
'''
Punto 18. Leer una matriz cuadrada A, obtener su matriz triangular superior 
asociada U y determinar qué fila de U contiene la mayor cantidad de unos. 
'''

# Condicionaremos al usuario de que solo puede entregar una dimensión de matriz
# positivo y unicamente un número entero.
while True:
    try:
        dim = int(input('Ingrese la dimensión de la matriz: '))
        if dim >= 0:
            break
        else:
            print('La dimensión de la matriz debe ser positiva.')
            
    except ValueError:
        print ('Entrada inválida, la dimensión de la matriz debe ser positiva'
               ' y un número entero.')

# Crearemos 3 listas que nos almacenarán valores para:
matriz = []        # filas de la matriz, por listas.
triangular_U = []        # La matriz triangular
uno = []           # Almacenará los unos de cada fila de triangular

# Ahora pediremos que ingrese cada número fila a fila de la matriz.
print('Ingrese los elementos de la matriz uno a uno, fila a fila de izquierda' 
      ' a derecha.')

# Se creará una lista por cada fila de la matriz, así hasta llenar las filas. 
# Deberá cumplir con que es un número y es positivo, de lo contrario el 
# programa pedirá que se cumplan las condiciones para ejecutarse.
while True:
    try:
        matriz = [[int(input()) for
                   m in range(dim)] for n in range(dim)]
        # "m" y "n" hacen referencia al tamaño de la matriz, n*m
        break
    except ValueError:
        print('Entradas inválidas, debe ingresar solo número enteros' 
              ' positivos. Intente de nuevo.')
 
# Calcularemos la matriz triangular asociada la lista "triangular_U".
for i in range(dim):
    fila = []
    for j in range(dim):
        if (j < i): 
            # si algun elemento está debajo de la diagonal de la matriz, se 
            # volverá 0, de lo contrario no cambia.
            fila.append(0)
        else:
            fila.append(matriz[i][j])
    triangular_U.append(fila)
    
print ('la matriz triangular superior asociada a la matriz es: ')
print()
for fila in triangular_U:
    print(fila) 
    # Obtendremos la matriz resultante, o sea la triangular superior.
    
#Obtendremos una lista con la cantidad de ceros que ha  en la matriz triangular
for i in range(dim):
    cantidad = ''
    for j in triangular_U[i]:
        if j == 1:
            cantidad += str(j)
        else:
            cantidad += ''
    uno.append(cantidad)
    
# Debemos encontra que fila tiene la mayor cantidad de ceros.
for i in uno:
    if i == max(uno):
        print ()
print('La fila con mayor cantidad de unos, es la fila',
              str(uno.index(i)))
print('En el caso que la mayor cantidad de unos esté en "la fila 0", es de' 
      ' entender que no hay ningun número 1 en alguna fila.')

# %%
'''
Punto 19. Leer una lista e identifique la sublista más larga dentro de dicha 
lista que se encuentra ordenada ascendentemente. Por ejemplo, en la lista [5, 
6, 5, 1, 2, 6, 9, 2, 4, 1] la mayor sublista ordenada es la [1, 2, 6, 9]. 
'''

# Debemos condicionar a que el usuario solo ingrese un tamaño de lista válido
# como dimensión para una lista, es decir, positivo y entero.
while True:
    try:
        tamaño_lista = int(input('Ingrese el tamaño de la lista: '))
        if tamaño_lista > 0  :
            break
        else:
            print('El tamaño de la lista no puede ser negativo, ni cero;'
                  ' entrada inválida.')
    except ValueError:
        print('Entrada inválida, ingrese número entero positivo.')

# Necesitamos una lista vacía para más tarde, agregar los elementos que el 
# usuario agregará.
lista = []                             

# Debemos condicionar a que solo podemos ingresar el número de datos a la lista 
# que hemos ingresado, para que lea como se debe, se le debe restar 1.
while len(lista) <= (tamaño_lista - 1):     
    lista.append((int(input('Digite los números de la lista uno a uno; por' 
                            ' cada entrada presione ENTER, hasta completar el' 
                            ' tamaño de lista escogida: '))))
                  
# Creamos una nueva lista vacía para almacenar datos que hallaremos más tarde.                                                     
lista_0 = []

# Creamos un ciclo que está al rededor de la longitud o tamaño de lista para
# determinar que elementos hacen parte de la sublista más larga de la lista
# ingresada por el usuario.
for i in range(len(lista)):
    aux = i       
    aux_2 = -1  #Variables auxiliares para la identación de listas ascendentes
    for j in range(i, len(lista)-1): #Separa las sublistas de forma ascendente
        if lista[j] <= lista[j+1]:
            aux_2 = j+1
        else:
            break
    lista_0.append(lista[aux:aux_2+1])
    
# Crearemos una lista que nos guardará los datos de la sublista más larga.
lista_mayor = lista_0[0]
for i in lista_0:                   
    if len(i) >= len(lista_mayor):
        lista_mayor = i   #Determina y separa la sublista ascendente mas larga
    
print('La lista que evaluamos, es: ', lista)
print()

if len(lista_mayor) == 0:
    print('No hallamos una sublista.')   
else:
    print(f'La sublista más larga, ordenada ascendentemente es: {lista_mayor}')

# %%
'''
Punto 20.a Hacer un programa que lea una matriz y la rote 90 grados en sentido 
antihorario. Imprimir la matriz resultante. Repita el mismo ejercicio 
utilizando el módulo numpy. 
'''

def read_matrix():
# La función leerá una matriz que el usuario ingresará con la estructura de 
# listas y sublistas.
    while True:
        try:
            matriz_20= eval(input('Introduzca una matriz, recuerde que la '
                                  'matriz es una lista que tiene listas, con ' 
                                  'una estructura de la forma [[],[],...], ' 
                                  'cada sublista es una fila de la matriz: '))
            if type(matriz_20) is list:
                for fila_matrix in matriz_20:
                    if type(fila_matrix) is list:
                        for entrada_matrix in fila_matrix:
                            if type(entrada_matrix) is not int:
                                raise Exception
                    else:
                        raise Exception
            else:
                raise Exception
            
            for Fila in matriz_20:
                if len(Fila) != len(matriz_20[0]) :
                    raise Exception
            break     
        except:
            print('Debe ser una matriz de numeros enteros con todas sus filas'
                  ' iguales.')
            
    return matriz_20

# Creamos una función para que las listas que se ingresen, queden en formato 
# fila - columna.
def Imprimir_matriz(MATRIX):
    for fila in MATRIX:
        for columna in fila:
            print('{:8}'.format(columna),end=' ')
        print()

# Usamos la función creada para leer la entrada del usuario
Matriz_M = read_matrix()
print()

Imprimir_matriz(Matriz_M)
print()

# Imprime la matriz rotada 90° en sentido antihorario teniendo en cuenta las 
# posiciones de la matriz introducida por el usuario.
print('La matriz rotada 90° en sentido antihorario es : ')
for Columna in range(len(Matriz_M[0])) :
    for Fila in range(len(Matriz_M)) :
        print('{:8}'.format(Matriz_M[Fila][len(Matriz_M[0])-Columna-1]),\
end = ' ')
    print()

# %%
'''
Punto 20.b Con libreria numpy.
'''

# Con libreria numpy
import numpy as np 

# Condicionaremos al usuario que solo puede ingresar para tamaños de filas y 
# columnas, un valor entero positivo, de lo contrario el programa no se 
# ejecutará.
while True:
    try:
        filas = int(input("Ingrese el número de filas de la matriz: ")) 
        columnas = int(input("Ingrese el número de columnas de la matriz: "))
        if filas > 0 and columnas > 0 :
            break
        else:
            print('Debe ingresar unicamente valores positivos.')
            
    except:
        print('La entrada es inválida, ingrese número entero positivo.')
  
  
print('Introduzca los elementos de la matriz fila por fila'
      ' y separados por espacios. Debe ingresar'
      , filas*columnas, 'entradas y presionar ENTER): ')

# Se le pedirá al usuario ingresar cada uno de los elementos de la matriz
entradas = list(map(int, input().split())) 
  
# Imprimimos la matriz inicial con lo elementos ingresados por el usuario
matrix = np.array(entradas).reshape(filas, columnas) 
print('La matriz inicial es: ')   
print(matriz)

# Usamos la función rot90() de numpy para rotar 90° en sentido antihorario la 
# matriz original, y despues imprimirla.
matriz_rot = np.rot90(matriz)  
print('La matriz rotada 90 grados en sentido antihorario es: ')
print(matriz_rot)
